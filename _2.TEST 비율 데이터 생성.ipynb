# %%
import pandas as pd

# %%
pd.read_csv('data/변수중요도.csv')
# Out:
#       Catboost      변수중요도 RandomForest   변수중요도.1         XGB       변수중요도.2  \
# 0      단지내주차면수  27.974759      단지내주차면수  0.563962     단지내주차면수  2.690195e-01
# 1          총면적  21.012296          총면적  0.222827       대전광역시  1.253529e-01
# 2        규모별가격  12.812154        규모별가격  0.027713         총면적  1.103567e-01
# 3   전용면적_25_비율   3.577833         총세대수  0.015322         A비율  6.710236e-02
# 4         총세대수   2.683418   전용면적_25_비율  0.015105     70대(남자)  6.105294e-02
# 5      ABEGH비율   2.585608          공가수  0.014930       아파트비율  5.304211e-02
# 6      80대(남자)   1.899604   전용면적_35_비율  0.012750    JKLMNO비율  4.899129e-02
# 7   전용면적_35_비율   1.804313   전용면적_45_비율  0.007967     50대(남자)  2.806111e-02
# 8      70대(남자)   1.744006   전용면적_50_비율  0.007805        장기비율  2.275227e-02
# 9          공가수   1.537104      40대(남자)  0.007094   10대미만(여자)  2.271154e-02
# 10     40대(여자)   1.437015      80대(남자)  0.005471     40대(남자)  1.955921e-02
# 11         A비율   1.303885        버스정류장  0.005327     20대(남자)  1.843438e-02
# 12     50대(여자)   1.283817   전용면적_55_비율  0.004749       초장기비율  1.535145e-02
# 13     20대(남자)   1.174396   전용면적_70_비율  0.004343  전용면적_50_비율  1.059298e-02
# 14     ACEFI비율   1.025079          A비율  0.003950  전용면적_25_비율  1.046280e-02
# 15   운전면허소지자비율   0.981280      20대(남자)  0.003837         연면적  9.461919e-03
# 16  전용면적_55_비율   0.926011    운전면허소지자비율  0.003717  전용면적_30_비율  8.079645e-03
# 17  전용면적_50_비율   0.922697    10대미만(여자)  0.003602     10대(남자)  7.300888e-03
# 18    100대(여자)   0.918270      30대(남자)  0.003537        지하철역  7.246882e-03
# 19       초장기비율   0.894540   전용면적_80_비율  0.003403     80대(남자)  7.118584e-03
# 20  전용면적_80_비율   0.885237      50대(여자)  0.003290     자전거도로비율  6.057231e-03
# 21        단기비율   0.691662      50대(남자)  0.003247  전용면적_70_비율  5.565030e-03
# 22  전용면적_30_비율   0.572722        초장기비율  0.003088     30대(여자)  5.416316e-03
# 23         연면적   0.566541      80대(여자)  0.002979  전용면적_35_비율  5.301669e-03
# 24       아파트비율   0.561599      30대(여자)  0.002917  전용면적_80_비율  5.092173e-03
# 25     90대(남자)   0.559144      70대(남자)  0.002793         공가수  4.887076e-03
# 26    100대(남자)   0.542036   전용면적_75_비율  0.002753       규모별가격  4.621933e-03
# 27        장기비율   0.462163      90대(남자)  0.002294  전용면적_75_비율  4.384041e-03
# 28     20대(여자)   0.414831      90대(여자)  0.002158        총세대수  3.725204e-03
# 29     90대(여자)   0.409087      ACEFI비율  0.002156     30대(남자)  3.425915e-03
# 30        지하철역   0.385081     100대(여자)  0.002051    100대(여자)  3.414630e-03
# 31      1인당자동차   0.323609      20대(여자)  0.002048  전용면적_45_비율  3.144358e-03
# 32     자전거도로비율   0.317091     100대(남자)  0.001976     20대(여자)  3.082129e-03
# 33   10대미만(여자)   0.314720   전용면적_30_비율  0.001910       버스정류장  2.032399e-03
# 34  전용면적_15_비율   0.306577          연면적  0.001886     ACEFI비율  1.858313e-03
# 35  전용면적_45_비율   0.301506     JKLMNO비율  0.001845      1인당자동차  1.681098e-03
# 36     60대(여자)   0.294103      자전거도로비율  0.001820     40대(여자)  1.626054e-03
# 37     30대(남자)   0.286838      40대(여자)  0.001712   운전면허소지자비율  1.550384e-03
# 38       버스정류장   0.281711      ABEGH비율  0.001595   10대미만(남자)  1.306935e-03
# 39  전용면적_75_비율   0.267854      10대(남자)  0.001423    100대(남자)  1.226751e-03
# 40     50대(남자)   0.257607      70대(여자)  0.001227     10대(여자)  1.066215e-03
# 41     30대(여자)   0.249106         상가비율  0.001198     50대(여자)  9.934425e-04
# 42   10대미만(남자)   0.242228         충청남도  0.001194  전용면적_15_비율  8.934034e-04
# 43     10대(여자)   0.230999    10대미만(남자)  0.001139     90대(여자)  8.826762e-04
# 44  전용면적_70_비율   0.199961      10대(여자)  0.001090  전용면적_55_비율  8.721479e-04
# 45         D비율   0.184350       평균분양가격  0.001033     90대(남자)  7.405771e-04
# 46       서울특별시   0.176773        대전광역시  0.000953     80대(여자)  7.343029e-04
# 47  전용면적_40_비율   0.167666   전용면적_20_비율  0.000888     60대(남자)  6.933055e-04
# 48  전용면적_20_비율   0.145091          D비율  0.000880  전용면적_20_비율  5.223200e-04
# 49     70대(여자)   0.137772         단기비율  0.000862  전용면적_40_비율  3.197357e-04
# 50      평균분양가격   0.136805       1인당자동차  0.000834      평균분양가격  3.192807e-04
# 51     40대(남자)   0.136405      60대(여자)  0.000737        충청남도  2.760861e-04
# 52        상가비율   0.110409         지하철역  0.000726     70대(여자)  2.211290e-04
# 53     60대(남자)   0.092513      60대(남자)  0.000650         강원도  8.679783e-06
# 54         경기도   0.057057         장기비율  0.000621        경상남도  3.273387e-06
# 55       대전광역시   0.057011        아파트비율  0.000603     60대(여자)  1.765520e-06
# 56  전용면적_60_비율   0.041181   전용면적_15_비율  0.000579  전용면적_65_비율  5.152050e-07
# 57    JKLMNO비율   0.040420   전용면적_40_비율  0.000326       부산광역시  0.000000e+00
# 58  전용면적_65_비율   0.030132         경상남도  0.000226     제주특별자치도  0.000000e+00
# 59     80대(여자)   0.024475        광주광역시  0.000173        전라북도  0.000000e+00
# 60        경상북도   0.019360         경상북도  0.000133        전라남도  0.000000e+00
# 61         강원도   0.011866        울산광역시  0.000113       울산광역시  0.000000e+00
# 62        충청남도   0.008620          강원도  0.000107     세종특별자치시  0.000000e+00
# 63        경상남도   0.000000         전라남도  0.000073       서울특별시  0.000000e+00
# 64       광주광역시   0.000000         충청북도  0.000063        경상북도  0.000000e+00
# 65       대구광역시   0.000000          경기도  0.000061        상가비율  0.000000e+00
# 66     10대(남자)   0.000000        부산광역시  0.000036       대구광역시  0.000000e+00
# 67       부산광역시   0.000000   전용면적_65_비율  0.000029       광주광역시  0.000000e+00
# 68     세종특별자치시   0.000000        대구광역시  0.000026        단기비율  0.000000e+00
# 69       울산광역시   0.000000      세종특별자치시  0.000025         경기도  0.000000e+00
# 70        전라남도   0.000000         전라북도  0.000018         D비율  0.000000e+00
# 71        전라북도   0.000000      제주특별자치도  0.000011     ABEGH비율  0.000000e+00
# 72     제주특별자치도   0.000000        서울특별시  0.000010  전용면적_60_비율  0.000000e+00
# 73        충청북도   0.000000   전용면적_60_비율  0.000002        충청북도  0.000000e+00
#
#     ExtraTrees   변수중요도.3 Gradient Boost   변수중요도.4
# 0      단지내주차면수  0.339318        단지내주차면수  0.552158
# 1          총면적  0.253400            총면적  0.200053
# 2        규모별가격  0.106637          규모별가격  0.049478
# 3          A비율  0.023033     전용면적_25_비율  0.016041
# 4         총세대수  0.022811      10대미만(여자)  0.013885
# 5        초장기비율  0.022421            공가수  0.013667
# 6      ACEFI비율  0.017630     전용면적_35_비율  0.013562
# 7   전용면적_25_비율  0.015707        50대(남자)  0.013046
# 8          공가수  0.011459            A비율  0.012721
# 9   전용면적_75_비율  0.008898     전용면적_50_비율  0.010546
# 10       버스정류장  0.007523           총세대수  0.010426
# 11  전용면적_35_비율  0.007452          초장기비율  0.009783
# 12  전용면적_45_비율  0.006822     전용면적_80_비율  0.006374
# 13  전용면적_50_비율  0.006344     전용면적_75_비율  0.005340
# 14        상가비율  0.006117        ACEFI비율  0.005067
# 15  전용면적_80_비율  0.005960        80대(남자)  0.004903
# 16  전용면적_55_비율  0.005815        30대(남자)  0.004743
# 17     40대(남자)  0.005506        70대(남자)  0.004732
# 18       아파트비율  0.005206        90대(남자)  0.004622
# 19        충청남도  0.004945        40대(남자)  0.004401
# 20     90대(남자)  0.004870     전용면적_45_비율  0.004313
# 21     30대(남자)  0.004797            D비율  0.004241
# 22     50대(남자)  0.004549          버스정류장  0.003903
# 23         D비율  0.004278     전용면적_55_비율  0.003722
# 24    JKLMNO비율  0.004088           충청남도  0.002870
# 25        지하철역  0.003948     전용면적_30_비율  0.002348
# 26        단기비율  0.003818        ABEGH비율  0.002076
# 27     80대(남자)  0.003797        20대(남자)  0.002039
# 28     20대(남자)  0.003796      10대미만(남자)  0.001970
# 29     30대(여자)  0.003755        60대(여자)  0.001715
# 30       대전광역시  0.003574        80대(여자)  0.001575
# 31     20대(여자)  0.003264       100대(남자)  0.001567
# 32       광주광역시  0.003160     전용면적_70_비율  0.001350
# 33     70대(남자)  0.003004       100대(여자)  0.001309
# 34   10대미만(여자)  0.002922           장기비율  0.001059
# 35     10대(여자)  0.002850            연면적  0.000982
# 36     80대(여자)  0.002839        90대(여자)  0.000975
# 37     90대(여자)  0.002754        40대(여자)  0.000939
# 38   10대미만(남자)  0.002733     전용면적_20_비율  0.000761
# 39        장기비율  0.002560      운전면허소지자비율  0.000702
# 40     50대(여자)  0.002496        10대(남자)  0.000661
# 41     ABEGH비율  0.002436           지하철역  0.000598
# 42     세종특별자치시  0.002281         평균분양가격  0.000575
# 43     60대(남자)  0.002268     전용면적_65_비율  0.000428
# 44  전용면적_70_비율  0.002234        20대(여자)  0.000393
# 45     60대(여자)  0.002169     전용면적_40_비율  0.000234
# 46     70대(여자)  0.002016         1인당자동차  0.000227
# 47  전용면적_65_비율  0.002014        50대(여자)  0.000214
# 48  전용면적_30_비율  0.001989           상가비율  0.000184
# 49        충청북도  0.001940           경상북도  0.000169
# 50        경상남도  0.001894        자전거도로비율  0.000110
# 51  전용면적_20_비율  0.001868            경기도  0.000065
# 52     10대(남자)  0.001835        30대(여자)  0.000046
# 53    100대(남자)  0.001714        10대(여자)  0.000044
# 54       부산광역시  0.001690        70대(여자)  0.000038
# 55      평균분양가격  0.001672           충청북도  0.000021
# 56    100대(여자)  0.001641     전용면적_15_비율  0.000015
# 57     자전거도로비율  0.001514           경상남도  0.000009
# 58      1인당자동차  0.001512        60대(남자)  0.000008
# 59     40대(여자)  0.001431          서울특별시  0.000000
# 60   운전면허소지자비율  0.001054        제주특별자치도  0.000000
# 61        경상북도  0.001010           전라북도  0.000000
# 62         연면적  0.000895           전라남도  0.000000
# 63  전용면적_15_비율  0.000645          울산광역시  0.000000
# 64         강원도  0.000609        세종특별자치시  0.000000
# 65        전라북도  0.000567          부산광역시  0.000000
# 66       대구광역시  0.000556     전용면적_60_비율  0.000000
# 67        전라남도  0.000517          대전광역시  0.000000
# 68  전용면적_40_비율  0.000483          대구광역시  0.000000
# 69       울산광역시  0.000255          광주광역시  0.000000
# 70         경기도  0.000204       JKLMNO비율  0.000000
# 71       서울특별시  0.000102           단기비율  0.000000
# 72     제주특별자치도  0.000093            강원도  0.000000
# 73  전용면적_60_비율  0.000035          아파트비율  0.000000

# %% [markdown]
# # 비율컬럼 추가

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test.csv')

# %%
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 100)
pd.set_option('display.max_columns', 85)
# Out:
# pandas version:  1.2.5

# %%
df.columns = ['단지코드', '총세대수', '임대건물구분', '지역', '공급유형', '전용면적', '전용면적별세대수', '공가수',
       '자격유형', '임대보증금', '임대료', '지하철역', '버스정류장', '단지내주차면수']

# %% [markdown]
# ## 1. 데이터 오류 처리

# %%
error_list=['C2335', 'C1327', 'C1095', 'C2051', 'C1218', 'C1894', 'C2483', 'C1502', 'C1988', 'C2085', 'C1397', 'C2431', 'C1649', 'C1036', 'C2675'] 
len(error_list)
# Out:
# 15

# %%
df.단지코드.nunique()
# Out:
# 150

# %%
code_list = [i for i in df.단지코드.unique() if i not in error_list]
len(code_list)
# Out:
# 147

# %%
df_r = pd.DataFrame()

for i in code_list:
    temp = df[df.단지코드 == i]
    df_r = pd.concat([df_r, temp])

# %%
df_r.to_csv('data/test_0_semi.csv')

# %%
df = df_r.copy()

# %% [markdown]
# ## 2.결측치 처리

# %%
df['임대료'] = df.임대료.replace('-', np.nan)
df['임대보증금'] = df.임대보증금.replace('-', np.nan)

# %%
df['임대료'] = df['임대료'].fillna(0)
df['임대보증금'] = df['임대보증금'].fillna(0)

# %% [markdown]
# ### 지하철역수
# - 대전은 1, 충청남도는 0

# %%
np.mean(df[df['지역'] == '대전광역시']['지하철역'])
# Out:
# 1.2765957446808511

# %%
np.mean(df[df['지역'] == '충청남도']['지하철역'])
# Out:
# 0.0

# %%
df['지하철역'] = np.where((df.지역 =='대전광역시') & (df['지하철역'].isnull()), 1, df['지하철역'])
df['지하철역'] = np.where((df.지역 =='충청남도') & (df['지하철역'].isnull()), 0, df['지하철역'])

# %% [markdown]
# ## 3.이상치 처리

# %%
df.columns
# Out:
# Index(['단지코드', '총세대수', '임대건물구분', '지역', '공급유형', '전용면적', '전용면적별세대수', '공가수',
#        '자격유형', '임대보증금', '임대료', '지하철역', '버스정류장', '단지내주차면수'],
#       dtype='object')

# %%
plt.boxplot(df['버스정류장'])
plt.show()

# %%
q25 = np.percentile(df['버스정류장'], 25)
q75 = np.percentile(df['버스정류장'], 75)
IQR = q75 - q25
df['버스정류장'] = np.where(df['버스정류장'] > 7, 7, df['버스정류장'])

# %%
np.mean(df['버스정류장'])
# Out:
# 3.7331349206349205

# %%
plt.hist(df['버스정류장'])
# Out:
# (array([115., 252.,   0., 158.,   0., 134., 112.,   0.,  85., 152.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
df.to_csv('data/test_1_semi.csv', index=False)

# %%
#전처리 완료
df = pd.read_csv('data/test_1_semi.csv')

# %% [markdown]
# ## 4.그룹

# %% [markdown]
# ### 공급유형 그룹

# %%
df['period'] = np.where((df.공급유형=='영구임대')|(df.공급유형=='공공임대(50년)')|(df.공급유형=='공공분양'), 'exL',
        np.where((df.공급유형=='국민임대')|(df.공급유형 =='장기전세'), 'L', 'S'))

# %%
# from collections import Counter

# %%
plt.hist(df.period)
# Out:
# (array([614.,   0.,   0.,   0.,   0.,  56.,   0.,   0.,   0., 338.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 자격유형 그룹

# %%
ls=[]
for i in df.공급유형.unique():
    temp = df[df.공급유형 == i]
    cert = temp.자격유형.unique()
    ls.append([i, cert])

# %% [markdown]
# - A : 공공임대(50년), 공공임대(10년), 공공임대(분납), 장기전세, 공공임대(5년) -
# - D : 임대상가, 공공분양 -
# - A, C, E, F, I : 영구임대
# - J, K, L, M, N, O : 행복주택
# - A, B, E, G, H : 국민임대

# %%
df['자격유형_cat'] = np.where(df.공급유형 =='행복주택', 'JKLMNO',
        np.where(df.공급유형 == '국민임대', 'ABEGH',
                np.where(df.공급유형 =='영구임대', 'ACEFI',
                        np.where((df.공급유형 =='임대상가') | (df.공급유형 =='공공분양'), 'D', 'A'))))

# %%
df['자격유형_cat'].unique()
# Out:
# array(['ABEGH', 'ACEFI', 'D', 'A', 'JKLMNO'], dtype=object)

# %%
plt.hist(df['자격유형_cat'])
# Out:
# (array([614.,   0.,  43.,   0.,   0., 177.,   0.,  54.,   0., 120.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 전용면적 그룹
# - 상한선 100, 하한선 15

# %%
df.전용면적.describe()
# Out:
# count    1008.000000
# mean       43.788462
# std        36.105647
# min         9.960000
# 25%        33.150000
# 50%        39.720000
# 75%        47.410000
# max       583.400000
# Name: 전용면적, dtype: float64

# %%
df['전용면적'] = df.전용면적//5 *5

# %%
df.전용면적 = np.where(df.전용면적 > 80, 80,
        np.where(df.전용면적 < 15, 15, df.전용면적))
df.전용면적 = df.전용면적.astype('int64')

# %%
df.전용면적.describe()
# Out:
# count    1008.000000
# mean       38.611111
# std        13.228027
# min        15.000000
# 25%        30.000000
# 50%        35.000000
# 75%        45.000000
# max        80.000000
# Name: 전용면적, dtype: float64

# %%
plt.hist(df.전용면적)
# Out:
# (array([109., 129.,  41., 285., 205., 136.,  68.,   0.,   8.,  27.]),
#  array([15. , 21.5, 28. , 34.5, 41. , 47.5, 54. , 60.5, 67. , 73.5, 80. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 5. 데이터프레임 만들기 시작

# %%
df1 = pd.DataFrame(df.groupby('단지코드').sum().reset_index()['단지코드'], columns=['단지코드']) #단지코드 데이터프레임

# %% [markdown]
# ## 1)임대건물구분

# %% [markdown]
# ### 아파트/상가 세대수

# %%
df1 = pd.DataFrame(df.groupby('단지코드').sum()['전용면적별세대수'].reset_index()['단지코드'], columns = ['단지코드'])
temp = df.groupby(['단지코드', '임대건물구분']).sum()['전용면적별세대수'].reset_index()

df1 = df1.merge(temp.loc[temp['임대건물구분'] == '아파트'].reset_index(drop=True)[['단지코드','전용면적별세대수']], on = '단지코드', how = 'left')

df1.columns = ['단지코드','아파트세대수']

df1 = df1.merge(temp.loc[temp['임대건물구분'] == '상가'].reset_index(drop=True)[['단지코드','전용면적별세대수']], on = '단지코드', how = 'left' )

df1.columns = ['단지코드','아파트세대수', '상가세대수']

df1 = df1.fillna(0)

# %% [markdown]
# ### 총세대수 & 아파트/상가 비율

# %%
# temp = df[['단지코드', '총세대수']].drop_duplicates() #총세대수
# df1 = df1.merge(temp, on='단지코드', how='left')

# %%
df1['총세대수'] = df1['아파트세대수'] + df1['상가세대수']

# %%
df1['아파트비율'] = df1['아파트세대수']/df1['총세대수']
df1['상가비율'] = df1['상가세대수']/df1['총세대수']

# %%
df1 = df1.drop(['아파트세대수', '상가세대수'], axis=1)

# %% [markdown]
# ## 2) 기본정보

# %%
#제외 : 총세대수, 임대건물구분(df1), 전용면적별세대수, 전용면적, 공급유형, 자격유형
#포함 : 단지코드, 지역, 공가수, 도보 10분거리 내 지하철역 수(환승노선 수 반영),  도보 10분거리 내 버스정류장 수, 단지내주차면수, 등록차량수

# %%
temp = df[['단지코드', '지역', '공가수', '지하철역',
                     '버스정류장', '단지내주차면수']].drop_duplicates()
df1=df1.merge(temp, on='단지코드', how='left')

# %%
#비율만
df1.columns = ['단지코드', '총세대수', '아파트비율', '상가비율', '지역', '공가수',
       '지하철역', '버스정류장', '단지내주차면수']

# %% [markdown]
# ## 3) 전용면적

# %%
for i in df.sort_values('전용면적').전용면적.unique():
    temp = df[df.전용면적 ==i].groupby('단지코드').sum().reset_index()[['단지코드', '전용면적별세대수']]
    temp.columns = ['단지코드', '전용면적_{}_세대수'.format(i)]
    df1 = df1.merge(temp,on='단지코드', how='left')
    
df1 = df1.fillna(0)

# %% [markdown]
# ## 4) 공급유형

# %% [markdown]
# ### 공급유형 cat 비율

# %%
df2 = pd.DataFrame(df.groupby('단지코드').sum().reset_index()['단지코드'], columns=['단지코드']) #단지코드 데이터프레임

temp = df.groupby(['단지코드', 'period']).sum().reset_index()

temp1 = temp.loc[temp['period'] == 'exL'][['단지코드', '전용면적별세대수']]
temp1.columns = ['단지코드', '초장기세대수']
df2 = df2.merge(temp1, on = '단지코드', how = 'left')

temp2 = temp.loc[temp['period'] == 'L'][['단지코드', '전용면적별세대수']]
temp2.columns = ['단지코드', '장기세대수']
df2 = df2.merge(temp2, on = '단지코드', how = 'left')

temp3 = temp.loc[temp['period'] == 'S'][['단지코드', '전용면적별세대수']]
temp3.columns = ['단지코드', '단기세대수']
df2 = df2.merge(temp3, on = '단지코드', how = 'left')

df2 = df2.fillna(0)

# %%
df2['총세대수'] = df2['초장기세대수'] + df2['장기세대수'] + df2['단기세대수']
df2['초장기비율'] = df2['초장기세대수'] / df2['총세대수']
df2['장기비율'] = df2['장기세대수'] / df2['총세대수']
df2['단기비율'] = df2['단기세대수'] / df2['총세대수']
df2 = df2.drop(['초장기세대수', '장기세대수', '단기세대수', '총세대수'], axis=1)
df1 = df1.merge(df2, on='단지코드', how='left')

# %% [markdown]
# ## 5) 자격유형

# %% [markdown]
# ### 자격유형cat 비율

# %%
df['자격유형_cat'].unique()
# Out:
# array(['ABEGH', 'ACEFI', 'D', 'A', 'JKLMNO'], dtype=object)

# %%
df2 = pd.DataFrame(df.groupby('단지코드').sum().reset_index()['단지코드'], columns=['단지코드']) #단지코드 데이터프레임

temp = df.groupby(['단지코드', '자격유형_cat']).sum().reset_index()

temp1 = temp.loc[temp['자격유형_cat'] == 'ABEGH'][['단지코드', '전용면적별세대수']]
temp1.columns = ['단지코드', 'ABEGH세대수']
df2 = df2.merge(temp1, on = '단지코드', how = 'left')

temp2 = temp.loc[temp['자격유형_cat'] == 'A'][['단지코드', '전용면적별세대수']]
temp2.columns = ['단지코드', 'A세대수']
df2 = df2.merge(temp2, on = '단지코드', how = 'left')

temp3 = temp.loc[temp['자격유형_cat'] == 'ACEFI'][['단지코드', '전용면적별세대수']]
temp3.columns = ['단지코드', 'ACEFI세대수']
df2 = df2.merge(temp3, on = '단지코드', how = 'left')

temp4 = temp.loc[temp['자격유형_cat'] == 'D'][['단지코드', '전용면적별세대수']]
temp4.columns = ['단지코드', 'D세대수']
df2 = df2.merge(temp4, on = '단지코드', how = 'left')

temp5 = temp.loc[temp['자격유형_cat'] == 'JKLMNO'][['단지코드', '전용면적별세대수']]
temp5.columns = ['단지코드', 'JKLMNO세대수']
df2 = df2.merge(temp5, on = '단지코드', how = 'left')

df2 = df2.fillna(0)

df2['총세대수'] = df2.iloc[:, 1] + df2.iloc[:, 2] + df2.iloc[:, 3] + df2.iloc[:, 4] + df2.iloc[:, 5]
df2['ABEGH비율'] = df2['ABEGH세대수'] / df2['총세대수']
df2['A비율'] = df2['A세대수'] / df2['총세대수']
df2['ACEFI비율'] = df2['ACEFI세대수'] / df2['총세대수']
df2['D비율'] = df2['D세대수'] / df2['총세대수']
df2['JKLMNO비율'] = df2['JKLMNO세대수'] / df2['총세대수']

# %%
df2 = df2.drop(['ABEGH세대수', 'A세대수', 'ACEFI세대수', 'D세대수', 'JKLMNO세대수', '총세대수'], axis=1)

# %%
df1 = df1.merge(df2, on='단지코드', how='left')

# %% [markdown]
# ## 6) 나이/성별 인구수
# - 나이대별로 합치는건 결과에 그다지 영향 안 미침. 그대로 붙여도 무관

# %%
ageinfo = pd.read_csv('data/age_gender_info.csv')
df1 = df1.merge(ageinfo, on = '지역', how = 'left')

# %% [markdown]
# ## 7) 1인당 자동차등록수

# %%
car_2019 = pd.read_csv('data/1인당자동차_2019.csv', encoding='euc-kr', header=1)

# %%
car_2019.columns = ['지역', '1인당_자동차등록대수', '자동차등록대수', '주민등록인구']
car_2019['1인당자동차'] = car_2019.자동차등록대수 / car_2019.주민등록인구
car_2019 = car_2019[['지역', '1인당자동차']]
df1 = df1.merge(car_2019, on='지역', how='left')

# %% [markdown]
# ## 8) 주택연면적

# %%
size = pd.read_csv('data/주택연면적_2019.csv', encoding='euc-kr', header=1)

# %%
size = size[['행정구역별(시군구)', '2019년']].iloc[4:, :].reset_index(drop=True)
size.columns = ['지역', '연면적']

# %%
df1 = df1.merge(size, on='지역', how='left')

# %% [markdown]
# ## 9) 평당가격

# %%
price = pd.read_csv('data/평균분양가격_2019.csv', encoding='euc-kr', header=1)
price = price[['지역별(2)', '전체.11']]
price = price.iloc[2:, :]
idx = price.index.difference([5]).difference([12]).difference([3]).difference([2])
price = price.loc[idx, :].reset_index(drop=True)
price.columns = ['지역', '평균분양가격']

# %%
price['지역'] = df.sort_values('지역').지역.unique()

# %%
df1 = df1.merge(price, on='지역', how='left')

# %% [markdown]
# ### 자전거도로현황

# %%
bicycle = pd.read_csv('자전거도로_2019.csv', encoding='euc-kr', header=1)
bicycle = bicycle.iloc[:, :2]
bicycle.columns = ['지역', '자전거도로']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-533-f9f9a87c5604> in <module>
# ----> 1 bicycle = pd.read_csv('자전거도로_2019.csv', encoding='euc-kr', header=1)
#       2 bicycle = bicycle.iloc[:, :2]
#       3 bicycle.columns = ['지역', '자전거도로']
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     704                 encoding=ioargs.encoding,
#     705                 errors=errors,
# --> 706                 newline="",
#     707             )
#     708         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '자전거도로_2019.csv'

# %%
df1 = df1.merge(bicycle, on='지역', how='left')

# %% [markdown]
# ## 10) 총면적구하기 ★

# %%
size_ls = df.sort_values('전용면적')['전용면적'].unique()

# %%
len(size_ls)
# Out:
# 13

# %%
all_size=0
for i in range(13):
    all_size += df1.iloc[:,i+9] * size_ls[i]

# %%
df1['총면적'] = all_size

# %% [markdown]
# ## 11) 규모별 가격

# %%
df1['규모별가격'] = df1['총면적'] * df1['평균분양가격']

# %%
df1.shape
# Out:
# (147, 57)

# %% [markdown]
# ## 12) 지역인코딩

# %%
df1 = pd.concat([df1.drop('지역', axis = 1),pd.get_dummies(df1.지역)], axis = 1)

# %%
# df1.to_csv('data/test_ratio.csv', index=False) #비율만

# %%
# df1.to_csv('data/test_ratio_count.csv', index=False) #비율 + 여부

# %% [markdown]
# ### 비율만 넣은 것

# %%
df1 = pd.read_csv('data/test_ratio.csv') #비율만 넣은 것

# %%
# df1 = pd.read_csv('data/test_3_semi.csv') #비율 + 여부

# %% [markdown]
# # Submission 12
# - 비율만 넣은 것 106

# %% [markdown]
# #### 모델 부르기

# %%
import pickle
with open('model_ereg1_ratio.pickle', 'rb') as fp:
    model = pickle.load(fp)

# %%
X = df1.iloc[:, 1:]
# Out:
# array([ 228.86672869,  246.79125802,  703.63773361,  301.42271677,
#          27.29537607,  260.75457237,  368.64926793,  627.96839625,
#         695.20722636,  496.79757739,  703.07335175,  417.87267761,
#         961.08788814, 1253.23280236,  246.35013802,  779.21574724,
#         601.3377587 ,  907.84324561,  254.32933426,  308.40697556,
#         291.04141032,  750.75958927,  314.14144567,  193.05042665,
#         304.31285027,  443.19969308,  976.50152828,  794.0988568 ,
#         410.18657644,  330.01260147,  491.5198643 ,  373.50533939,
#         580.95447719,  485.79695071,  233.07677417,  288.67495821,
#         448.88221559, 1205.44913131,  287.80870785,  342.6485849 ,
#         642.03846571,  406.91941405,  869.21243482,  472.50567238,
#         490.56462748,  489.43242627,  157.48865042, 1136.97740443,
#         983.2994894 , 1186.79240487, 1180.85856986, 1215.43559847,
#        1686.53129774,  337.78678428,  719.93480326,  274.23375446,
#         359.36102764,  532.21465717,  427.17191901, 1055.48162636,
#         567.27390286,  309.79787067,  236.29941642,  165.1667296 ,
#         474.84939712,  481.80957902,  208.04230888,  890.1891107 ,
#         337.75564448,  613.35426442,  595.97958902,   88.04663324,
#         442.17089297,  412.89928342,  558.13577604,  502.76840961,
#         907.27413109,   85.78174382,  220.76133303,  425.72473378,
#         746.82253289,  724.26014036,  516.98928261,   98.18116125,
#         542.40941711,  684.49757892,  796.31119585,  277.40507851,
#         613.01342249,  751.83607739, 1356.58812675,  339.52431865,
#         903.57522679,  248.4163807 ,  221.43072381,  816.16605819,
#         144.48582225,  328.47532107,  544.78082813,  270.47785305,
#         566.93736847,  462.35131911,    7.66236562,  403.11387958,
#         885.38834237,  231.47269125,  141.57064851,  440.15832136,
#         363.73221921,  755.86284649,  150.98660086,  852.70257607,
#         355.42047956,  568.70785354,  738.60087763,  424.96263844,
#        1408.03250395,  277.93581538,  597.85418273,  358.77020702,
#         614.57210986,  402.5465077 ,  571.22408016,  136.95125881,
#         664.60286052,  376.83141781,  204.65360962,  707.42467183,
#         670.86723312,  561.47147459,  266.63378224,  980.92269205,
#         685.87330583,  378.82747266,  450.56368019,  524.75290766,
#         630.7967381 , 1429.60336339,  729.57986089,  438.9692615 ,
#         312.22647218, 1104.17936207,  514.97870741,  836.33581477,
#         275.11851423,  145.23348967, 1224.51131675])

# %% [markdown]
# #### SUBMISSION 생성

# %%
submission12 = pd.DataFrame({'code' : df1.단지코드, 'predict' : model.predict(X)}) #비율만 넣은 것 test_2_semi

# %%
sub = pd.read_csv('sample_submission.csv')
sub = sub.merge(submission12, on='code', how='left')
sub = sub.drop('num', axis=1)
sub.columns = ['code', 'num']
sub.to_csv('submission/submission12.csv', index=False)

# %% [markdown]
# # Submission 13
# - 비율 + 여부컬럼 108

# %% [markdown]
# #### 데이터 부르기

# %%
df1 = pd.read_csv('data/test_3_semi.csv') #비율 + 여부

# %% [markdown]
# #### 모델 부르기

# %%
import pickle
with open('model_ereg1_ratio_count.pickle', 'rb') as fp:
    model = pickle.load(fp)

# %%
X = df1.iloc[:, 1:]

# %%
submission13 = pd.DataFrame({'code' : df1.단지코드, 'predict' : model.predict(X)}) #비율+여부만 넣은 것 test_3_semi

# %%
sub = pd.read_csv('sample_submission.csv')
sub = sub.merge(submission13, on='code', how='left')
sub = sub.drop('num', axis=1)
sub.columns = ['code', 'num']
sub.to_csv('submission/submission13.csv', index=False)

# %% [markdown]
# ## Submission 14
# - 비율만 넣은 것 스케일링 121

# %%
import pickle
with open('model_ereg1_ratio_scaled.pickle', 'rb') as fp:
    model = pickle.load(fp)

# %%
submission14 = pd.DataFrame({'code' : df1.단지코드, 'predict' : model.predict(X)}) #비율만 넣은 것 test_2_semi

# %%
sub = pd.read_csv('sample_submission.csv')
sub = sub.merge(submission14, on='code', how='left')
sub = sub.drop('num', axis=1)
sub.columns = ['code', 'num']
sub.to_csv('submission/submission14.csv', index=False)
